# %% [markdown]
# # Notebook 01 — Ingesta de Datos
#
# Captura y normalización de microdatos de fuentes abiertas (INDEC y CABA).
#
# **Fuentes objetivo:**
# - IPC INDEC — Índice de Precios al Consumidor (nivel nacional)
# - Precios Claros / microdatos de CABA

# %%
import duckdb
import pandas as pd
import requests
from pathlib import Path

RAW_DIR = Path('../data/raw')
PROCESSED_DIR = Path('../data/processed')
DB_PATH = Path('../data/database/rst.duckdb')

# %% [markdown]
# ## 1. Descarga de datos crudos

# %%
# TODO: implementar descarga desde fuentes INDEC / CABA
pass

# %% [markdown]
# ## 2. Normalización y guardado en Parquet

# %%
# TODO: limpiar y estandarizar columnas, guardar como Parquet
pass

# %% [markdown]
# ## 3. Carga en DuckDB

# %%
con = duckdb.connect(str(DB_PATH))
# TODO: registrar tablas desde los Parquet procesados
con.close()
